# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
from scipy.stats import boxcox
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import mean_squared_error, accuracy_score, mean_absolute_error
from sklearn.neighbors import KNeighborsRegressor

# %%
data = pd.read_csv('housing.csv')

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
data.dropna(inplace = True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.7+ MB

# %%
X = data.drop(['median_house_value'], axis = 1)
y = data['median_house_value']

# %%
X
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income ocean_proximity
# 0           322.0       126.0         8.3252        NEAR BAY
# 1          2401.0      1138.0         8.3014        NEAR BAY
# 2           496.0       177.0         7.2574        NEAR BAY
# 3           558.0       219.0         5.6431        NEAR BAY
# 4           565.0       259.0         3.8462        NEAR BAY
# ...           ...         ...            ...             ...
# 20635       845.0       330.0         1.5603          INLAND
# 20636       356.0       114.0         2.5568          INLAND
# 20637      1007.0       433.0         1.7000          INLAND
# 20638       741.0       349.0         1.8672          INLAND
# 20639      1387.0       530.0         2.3886          INLAND
#
# [20433 rows x 9 columns]

# %%
y
# Out:
# 0        452600.0
# 1        358500.0
# 2        352100.0
# 3        341300.0
# 4        342200.0
#            ...
# 20635     78100.0
# 20636     77100.0
# 20637     92300.0
# 20638     84700.0
# 20639     89400.0
# Name: median_house_value, Length: 20433, dtype: float64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %%
train_data = X_train.join(y_train)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 5400     -118.43     34.03                26.0       1706.0           516.0
# 14329    -117.17     32.71                39.0        311.0           181.0
# 8330     -118.30     33.93                35.0       1300.0           356.0
# 3995     -118.58     34.17                29.0       3393.0           574.0
# 13544    -117.30     34.15                45.0        942.0           166.0
# ...          ...       ...                 ...          ...             ...
# 8308     -118.10     33.76                15.0       4690.0          1002.0
# 3736     -118.40     34.18                32.0       3724.0           899.0
# 1343     -121.89     38.01                32.0       1000.0           188.0
# 11572    -118.01     33.76                26.0       2141.0           597.0
# 3728     -118.43     34.18                31.0       2417.0           510.0
#
#        population  households  median_income ocean_proximity  \
# 5400        894.0       435.0         3.1875       <1H OCEAN
# 14329       206.0       113.0         0.7685      NEAR OCEAN
# 8330       1216.0       326.0         1.2000       <1H OCEAN
# 3995       1471.0       587.0         6.2064       <1H OCEAN
# 13544       401.0       174.0         3.8594          INLAND
# ...           ...         ...            ...             ...
# 8308       1879.0       974.0         5.6051      NEAR OCEAN
# 3736       1912.0       791.0         3.5711       <1H OCEAN
# 1343        663.0       212.0         4.0972          INLAND
# 11572      2038.0       585.0         2.2981       <1H OCEAN
# 3728       1102.0       507.0         3.8906       <1H OCEAN
#
#        median_house_value
# 5400             372700.0
# 14329            187500.0
# 8330              99200.0
# 3995             334900.0
# 13544             90800.0
# ...                   ...
# 8308             267400.0
# 3736             312700.0
# 1343              99200.0
# 11572            177700.0
# 3728             282200.0
#
# [16346 rows x 10 columns]

# %%
train_data_without_op = train_data.drop(['ocean_proximity'], axis = 1)

# %%
train_data_without_op
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 5400     -118.43     34.03                26.0       1706.0           516.0
# 14329    -117.17     32.71                39.0        311.0           181.0
# 8330     -118.30     33.93                35.0       1300.0           356.0
# 3995     -118.58     34.17                29.0       3393.0           574.0
# 13544    -117.30     34.15                45.0        942.0           166.0
# ...          ...       ...                 ...          ...             ...
# 8308     -118.10     33.76                15.0       4690.0          1002.0
# 3736     -118.40     34.18                32.0       3724.0           899.0
# 1343     -121.89     38.01                32.0       1000.0           188.0
# 11572    -118.01     33.76                26.0       2141.0           597.0
# 3728     -118.43     34.18                31.0       2417.0           510.0
#
#        population  households  median_income  median_house_value
# 5400        894.0       435.0         3.1875            372700.0
# 14329       206.0       113.0         0.7685            187500.0
# 8330       1216.0       326.0         1.2000             99200.0
# 3995       1471.0       587.0         6.2064            334900.0
# 13544       401.0       174.0         3.8594             90800.0
# ...           ...         ...            ...                 ...
# 8308       1879.0       974.0         5.6051            267400.0
# 3736       1912.0       791.0         3.5711            312700.0
# 1343        663.0       212.0         4.0972             99200.0
# 11572      2038.0       585.0         2.2981            177700.0
# 3728       1102.0       507.0         3.8906            282200.0
#
# [16346 rows x 9 columns]

# %%
train_data_without_op.corr()
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.923385           -0.113250     0.051233
# latitude            -0.923385  1.000000            0.013694    -0.041787
# housing_median_age  -0.113250  0.013694            1.000000    -0.360954
# total_rooms          0.051233 -0.041787           -0.360954     1.000000
# total_bedrooms       0.074628 -0.071000           -0.321819     0.930844
# population           0.105101 -0.113250           -0.298353     0.855885
# households           0.061910 -0.076532           -0.304773     0.919334
# median_income       -0.015556 -0.081449           -0.112904     0.192607
# median_house_value  -0.043516 -0.148755            0.108985     0.129027
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.074628    0.105101    0.061910      -0.015556
# latitude                 -0.071000   -0.113250   -0.076532      -0.081449
# housing_median_age       -0.321819   -0.298353   -0.304773      -0.112904
# total_rooms               0.930844    0.855885    0.919334       0.192607
# total_bedrooms            1.000000    0.876388    0.979358      -0.011317
# population                0.876388    1.000000    0.906340       0.003441
# households                0.979358    0.906340    1.000000       0.009987
# median_income            -0.011317    0.003441    0.009987       1.000000
# median_house_value        0.044527   -0.027290    0.059786       0.688892
#
#                     median_house_value
# longitude                    -0.043516
# latitude                     -0.148755
# housing_median_age            0.108985
# total_rooms                   0.129027
# total_bedrooms                0.044527
# population                   -0.027290
# households                    0.059786
# median_income                 0.688892
# median_house_value            1.000000

# %%
train_data_without_op.hist(figsize = (15, 8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
plt.figure(figsize = (15, 8))
sns.heatmap(train_data_without_op.corr(), annot = True, cmap = "YlGnBu")
# Out:
# <Axes: >

# %%
train_data2 = train_data_without_op

# %%
transformed_households, lambda_value1 = boxcox(train_data2['households'])
transformed_totalsbedrooms, lambda_value2 = boxcox(train_data2['total_bedrooms'])
transformed_population, lambda_value3 = boxcox(train_data2['population'])
transformed_totalrooms, lambda_value4 = boxcox(train_data2['total_rooms'])

# %%
train_data2['households'] = transformed_households
train_data2['total_bedrooms'] = transformed_totalsbedrooms
train_data2['total_rooms'] = transformed_totalrooms
train_data2['population'] = transformed_population

# %%
train_data2.hist(figsize = (15, 8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %% [markdown]
# # Start preprocess

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20433 rows x 10 columns]

# %%
data.ocean_proximity.value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     9034
# INLAND        6496
# NEAR OCEAN    2628
# NEAR BAY      2270
# ISLAND           5
# Name: count, dtype: int64

# %%
pd.get_dummies(train_data.ocean_proximity)
# Out:
#        <1H OCEAN  INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 5400        True   False   False     False       False
# 14329      False   False   False     False        True
# 8330        True   False   False     False       False
# 3995        True   False   False     False       False
# 13544      False    True   False     False       False
# ...          ...     ...     ...       ...         ...
# 8308       False   False   False     False        True
# 3736        True   False   False     False       False
# 1343       False    True   False     False       False
# 11572       True   False   False     False       False
# 3728        True   False   False     False       False
#
# [16346 rows x 5 columns]

# %%
data = data.join(pd.get_dummies(data.ocean_proximity)).drop(['ocean_proximity'], axis = 1)

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 0           322.0       126.0         8.3252            452600.0      False
# 1          2401.0      1138.0         8.3014            358500.0      False
# 2           496.0       177.0         7.2574            352100.0      False
# 3           558.0       219.0         5.6431            341300.0      False
# 4           565.0       259.0         3.8462            342200.0      False
# ...           ...         ...            ...                 ...        ...
# 20635       845.0       330.0         1.5603             78100.0      False
# 20636       356.0       114.0         2.5568             77100.0      False
# 20637      1007.0       433.0         1.7000             92300.0      False
# 20638       741.0       349.0         1.8672             84700.0      False
# 20639      1387.0       530.0         2.3886             89400.0      False
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 0       False   False      True       False
# 1       False   False      True       False
# 2       False   False      True       False
# 3       False   False      True       False
# 4       False   False      True       False
# ...       ...     ...       ...         ...
# 20635    True   False     False       False
# 20636    True   False     False       False
# 20637    True   False     False       False
# 20638    True   False     False       False
# 20639    True   False     False       False
#
# [20433 rows x 14 columns]

# %%
transformed_households, lambda_value4 = boxcox(data['households'])
transformed_totalsbedrooms, lambda_value2 = boxcox(data['total_bedrooms'])
transformed_population, lambda_value3 = boxcox(data['population'])
transformed_totalrooms, lambda_value1 = boxcox(data['total_rooms'])

data['households'] = transformed_households
data['total_bedrooms'] = transformed_totalsbedrooms
data['total_rooms'] = transformed_totalrooms
data['population'] = transformed_population

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0    15.711183        8.812635
# 1        -122.22     37.86                21.0    27.567255       17.043806
# 2        -122.24     37.85                52.0    18.129399       10.018273
# 3        -122.25     37.85                52.0    17.434442       10.726091
# 4        -122.25     37.85                52.0    18.653359       11.335470
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0    18.771858       12.396339
# 20636    -121.21     39.49                18.0    14.695478        9.269814
# 20637    -121.22     39.43                17.0    20.383726       13.409430
# 20638    -121.32     39.43                18.0    19.348787       12.738405
# 20639    -121.24     39.37                16.0    21.575190       14.395180
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 0       12.313702    9.276867         8.3252            452600.0      False
# 1       22.349787   18.837657         8.3014            358500.0      False
# 2       14.089610   10.438155         7.2574            352100.0      False
# 3       14.606008   11.216602         5.6431            341300.0      False
# 4       14.661511   11.859220         3.8462            342200.0      False
# ...           ...         ...            ...                 ...        ...
# 20635   16.544107   12.835209         1.5603             78100.0      False
# 20636   12.710336    8.952949         2.5568             77100.0      False
# 20637   17.422049   14.000827         1.7000             92300.0      False
# 20638   15.910079   13.069100         1.8672             84700.0      False
# 20639   19.121406   14.920037         2.3886             89400.0      False
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 0       False   False      True       False
# 1       False   False      True       False
# 2       False   False      True       False
# 3       False   False      True       False
# 4       False   False      True       False
# ...       ...     ...       ...         ...
# 20635    True   False     False       False
# 20636    True   False     False       False
# 20637    True   False     False       False
# 20638    True   False     False       False
# 20639    True   False     False       False
#
# [20433 rows x 14 columns]

# %%
data[['<1H OCEAN', 'INLAND', 'ISLAND', 'NEAR BAY', 'NEAR OCEAN']] = data[['<1H OCEAN', 'INLAND', 'ISLAND', 'NEAR BAY', 'NEAR OCEAN']].astype(int)

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0    15.711183        8.812635
# 1        -122.22     37.86                21.0    27.567255       17.043806
# 2        -122.24     37.85                52.0    18.129399       10.018273
# 3        -122.25     37.85                52.0    17.434442       10.726091
# 4        -122.25     37.85                52.0    18.653359       11.335470
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0    18.771858       12.396339
# 20636    -121.21     39.49                18.0    14.695478        9.269814
# 20637    -121.22     39.43                17.0    20.383726       13.409430
# 20638    -121.32     39.43                18.0    19.348787       12.738405
# 20639    -121.24     39.37                16.0    21.575190       14.395180
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 0       12.313702    9.276867         8.3252            452600.0          0
# 1       22.349787   18.837657         8.3014            358500.0          0
# 2       14.089610   10.438155         7.2574            352100.0          0
# 3       14.606008   11.216602         5.6431            341300.0          0
# 4       14.661511   11.859220         3.8462            342200.0          0
# ...           ...         ...            ...                 ...        ...
# 20635   16.544107   12.835209         1.5603             78100.0          0
# 20636   12.710336    8.952949         2.5568             77100.0          0
# 20637   17.422049   14.000827         1.7000             92300.0          0
# 20638   15.910079   13.069100         1.8672             84700.0          0
# 20639   19.121406   14.920037         2.3886             89400.0          0
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 0           0       0         1           0
# 1           0       0         1           0
# 2           0       0         1           0
# 3           0       0         1           0
# 4           0       0         1           0
# ...       ...     ...       ...         ...
# 20635       1       0         0           0
# 20636       1       0         0           0
# 20637       1       0         0           0
# 20638       1       0         0           0
# 20639       1       0         0           0
#
# [20433 rows x 14 columns]

# %%
X = data.drop(['median_house_value'], axis = 1)
y = data['median_house_value']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %%
train_data = X_train.join(y_train)

# %%
plt.figure(figsize = (15, 8))
sns.heatmap(train_data.corr(), annot = True, cmap = "YlGnBu")
# Out:
# <Axes: >

# %% [markdown]
# # End preprocess

# %% [markdown]
# ## Linear Regression

# %%
reg = LinearRegression()

# %%
reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
reg.score(X_test, y_test)
# Out:
# 0.6771448380828462

# %%
Scaler = StandardScaler()

# %%
X_train_scaler = Scaler.fit_transform(X_train)

# %%
reg.fit(X_train_scaler, y_train)
# Out:
# LinearRegression()

# %%
X_test_scaler = Scaler.transform(X_test)

# %%
reg.score(X_test_scaler, y_test)
# Out:
# 0.6771448380828462

# %%
y_pred = reg.predict(X_test_scaler)

# %%
mean_absolute_error(y_test, y_pred)
# Out:
# 48233.28128174941

# %%
test1 = np.array([[-122.25, 37.85, 52, 1627, 280, 565, 259, 3.8462, 0, 0, 0, 1, 0]])

# %%
lambdas = np.array([lambda_value1, lambda_value2, lambda_value3, lambda_value4])

# %%
test1[0, 3] = boxcox(test1[0, 3], lmbda=lambda_value1)
test1[0, 4] = boxcox(test1[0, 4], lmbda=lambda_value2)
test1[0, 5] = boxcox(test1[0, 5], lmbda=lambda_value3)
test1[0, 6] = boxcox(test1[0, 6], lmbda=lambda_value4)

# %%
test1
# Out:
# array([[-122.25      ,   37.85      ,   52.        ,   18.65335887,
#           11.33546984,   14.66151058,   11.85922002,    3.8462    ,
#            0.        ,    0.        ,    0.        ,    1.        ,
#            0.        ]])

# %%
test1_scaled = Scaler.transform(test1)
# Out:
# D:\Anaconda\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
test1_scaled
# Out:
# array([[-1.33266467,  1.03194339,  1.84494274, -0.40432395, -0.65346029,
#         -0.98955584, -0.67153817, -0.00467037, -0.88869193, -0.6827448 ,
#         -0.01354861,  2.8233774 , -0.38509278]])

# %%
reg.predict(test1_scaled)
# Out:
# array([260284.99927291])

# %% [markdown]
# ## Random forest

# %%
forest = RandomForestRegressor()

# %%
forest.fit(X_train_scaler, y_train)
# Out:
# RandomForestRegressor()

# %%
forest.score(X_test_scaler, y_test)
# Out:
# 0.8059044042801992

# %%
forest.predict(test1_scaled)
# Out:
# array([263108.01])

# %%
param_grid = {
    "n_estimators" : [50, 100, 200],
    "max_features" : [6, 12, 20],
    "min_samples_split":[2, 4, 6, 8]
}

grid_search = GridSearchCV(forest, param_grid, cv = 5, scoring = "neg_mean_squared_error", return_train_score = True)

grid_search.fit(X_train_scaler, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_features': [6, 12, 20],
#                          'min_samples_split': [2, 4, 6, 8],
#                          'n_estimators': [50, 100, 200]},
#              return_train_score=True, scoring='neg_mean_squared_error')

# %%
grid_search.best_estimator_
# Out:
# RandomForestRegressor(max_features=6, n_estimators=200)

# %%
best_forest = grid_search.best_estimator_

# %%
best_forest.score(X_test_scaler, y_test)
# Out:
# 0.8234906803434263

# %% [markdown]
# ## Neural network

# %%
model = MLPRegressor(hidden_layer_sizes=(64,), activation='relu', solver='adam', max_iter=2000, learning_rate_init=0.001, random_state=42)

model.fit(X_train_scaler, y_train)
# Out:
# D:\Anaconda\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (2000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLPRegressor(hidden_layer_sizes=(64,), max_iter=2000, random_state=42)

# %%
model.score(X_test_scaler, y_test)
# Out:
# 0.7057702308457219

# %% [markdown]
# ## KNN

# %%
neigh = KNeighborsRegressor(n_neighbors=4)

neigh.fit(X_train_scaler, y_train)
# Out:
# KNeighborsRegressor(n_neighbors=4)

# %%
neigh.score(X_test_scaler, y_test)
# Out:
# 0.727553695030362

# %%
neigh.predict(test1_scaled)
# Out:
# array([298775.])

# %%
param_grid = {
    'n_neighbors': [3, 4, 5, 6, 7, 8, 9],  
    'weights': ['uniform', 'distance'],
}

# %%
grid_search = GridSearchCV(neigh, param_grid, cv=5, scoring='neg_mean_squared_error')
grid_search.fit(X_train_scaler, y_train)
# Out:
# GridSearchCV(cv=5, estimator=KNeighborsRegressor(n_neighbors=4),
#              param_grid={'n_neighbors': [3, 4, 5, 6, 7, 8, 9],
#                          'weights': ['uniform', 'distance']},
#              scoring='neg_mean_squared_error')

# %%
grid_search.best_estimator_
# Out:
# KNeighborsRegressor(n_neighbors=9, weights='distance')

# %%
grid_search.best_estimator_.score(X_test_scaler, y_test)
# Out:
# 0.7329226329204548
